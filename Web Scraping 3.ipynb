# %%
# importing all the necessary libraries

from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException
import pandas as pd
import time

# %% [markdown]
# # Question 1

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
url = 'https://www.amazon.in'
driver.get(url)
# Out:
# <ipython-input-6-0a74fa245cef>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
# obtaining the search option on our web driver
search = driver.find_element_by_id('twotabsearchtextbox')
# Out:
# <ipython-input-7-e2d3e4d7141f>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id('twotabsearchtextbox')

# %%
# obtaining the item to be searched from the user
search = driver.find_element_by_id("twotabsearchtextbox")
item = str(input("Enter item name that you want to search: "))
search.send_keys(item)
# Out:
# <ipython-input-8-247f31e380ac>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("twotabsearchtextbox")
# Enter item name that you want to search: guitar

# %%
# performing a click using xpath function in our web driver
search_btn = driver.find_element_by_xpath("//span[@class='nav-search-submit-text nav-sprite nav-progressive-attribute']")
search_btn.click()
time.sleep(5)
# Out:
# <ipython-input-9-09b38c05f642>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("//span[@class='nav-search-submit-text nav-sprite nav-progressive-attribute']")

# %% [markdown]
# # Question 2

# %%
# getting all the urls to open each page from our above search results
urls =[]
for i in range(0,3): # upto 3 pages
    for x in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
        urls.append(x.get_attribute('href'))
    driver.find_element_by_xpath("//li[@class='a-last']/a").click()
    time.sleep(3)
# Out:
# <ipython-input-10-13fddbbc671c>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for x in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
# <ipython-input-10-13fddbbc671c>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//li[@class='a-last']/a").click()

# %%
# all the initial empty lists
brand=[]
prod_name=[]
rating=[]
rating_num=[]
price= []
ret_ex=[]
exp_del = []
availability=[]
prod_url=[]
ot_det = []

# obtaining all the details one after another
for i in urls[:150]:
    driver.get(i)
    time.sleep(3)
    
    # getting the brand name
    try:
        brand_name=driver.find_element_by_xpath("//td[@class='a-span9']/span")
        brand.append(brand_name.text)
    except NoSuchElementException:
        brand.append('-')    # getting the product name
    try:
        product=driver.find_element_by_id("productTitle")
        prod_name.append(product.text)
    except NoSuchElementException:
        prod_name.append('-')         
        
      # getting the rating
    try:
        ratestar=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
        rating.append(ratestar.text)
    except NoSuchElementException:
        rating.append("No Rating") 
        # getting the rating number
    try:
        ratenum=driver.find_element_by_id("acrCustomerReviewText")
        rating_num.append(ratenum.text)
    except NoSuchElementException:
        rating_num.append('-')         
                
      # getting the price
    try:
        prod_price=driver.find_element_by_id("priceblock_ourprice")
        price.append(prod_price.text)
    except NoSuchElementException:
        price.append('-')      
                
     # getting the return/exchange
    try:
        ret_exch=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
        ret_ex.append(ret_exch.get_attribute("href"))
    except NoSuchElementException:
        ret_ex.append('-') 
        # getting the expected delivery
    try:
        ex_de=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
        exp_del.append(ex_de.text)
    except NoSuchElementException:
        exp_del.append('-')           
               
     # getting the availability
    try:
        availa=driver.find_element_by_id("availability")
        availability.append(availa.text)
    except NoSuchElementException:
        availability.append('-')       
        # getting the product url
    try:
        pro_url=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content']/a")
        prod_url.append(pro_url.get_attribute("href"))
    except NoSuchElementException:
        prod_url.append('-')
        
     # getting the other details
    try:
        othr_det=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']/li/span")
        ot_det.append(othr_det.text)
    except NoSuchElementException:
        ot_det.append('-')
        
        # creating the entire dataframe now
item_df = pd.DataFrame({})
item_df['Brand Name'] = brand
item_df['Product Name'] = prod_name
item_df['Rating'] = rating
item_df['Rating Number'] = rating_num
item_df['Price'] = price
item_df['Return/Exchange'] = ret_ex
item_df['Expected Delivery'] = exp_del
item_df['Availability'] = availability
item_df['Product URLs'] = prod_url
item_df['Other Details'] = ot_det     
item_df
# Out:
# <ipython-input-12-2fa71485b480>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand_name=driver.find_element_by_xpath("//td[@class='a-span9']/span")
# <ipython-input-12-2fa71485b480>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   product=driver.find_element_by_id("productTitle")
# <ipython-input-12-2fa71485b480>:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratestar=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
# <ipython-input-12-2fa71485b480>:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratenum=driver.find_element_by_id("acrCustomerReviewText")
# <ipython-input-12-2fa71485b480>:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prod_price=driver.find_element_by_id("priceblock_ourprice")
# <ipython-input-12-2fa71485b480>:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ret_exch=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
# <ipython-input-12-2fa71485b480>:58: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ex_de=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
# <ipython-input-12-2fa71485b480>:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   availa=driver.find_element_by_id("availability")
# <ipython-input-12-2fa71485b480>:71: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro_url=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content']/a")
# <ipython-input-12-2fa71485b480>:78: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   othr_det=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']/li/span")
#        Brand Name                                       Product Name  \
# 0         Kadence  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 1         Kadence  Kadence Frontier Series, Acoustic Guitar With/...
# 2          JUAREZ  Juarez Acoustic Guitar, 38 Inch Curved Body Cu...
# 3           VAULT          Vault ST1 Premium Electric Guitar - White
# 4          Intern  Intern INT-38C Acoustic Guitar Kit, With Bag, ...
# ..            ...                                                ...
# 145        YAMAHA             Yamaha FS100C Acoustic Guitar, Natural
# 146    LAVINGSTON  LAVINGSTON Givson Venus Special Guitar combo (...
# 147      Medellin  Medellin 38in Premium All Wood Acoustic Guitar...
# 148     Blueberry  Blueberry 38 Inch Acoustic Guitar Kit Inbuilt ...
# 149  Martin Smith  Martin Smith W-101-N-PK Acoustic Guitar Super ...
#
#            Rating  Rating Number      Price  \
# 0    4.1 out of 5    302 ratings          -
# 1      4 out of 5  1,238 ratings  ₹5,199.00
# 2    3.9 out of 5  1,296 ratings  ₹2,190.00
# 3    3.9 out of 5     28 ratings  ₹7,599.00
# 4      4 out of 5  8,446 ratings  ₹2,350.00
# ..            ...            ...        ...
# 145  4.1 out of 5      7 ratings  ₹9,990.00
# 146     No Rating              -  ₹3,999.00
# 147    4 out of 5      6 ratings          -
# 148  3.2 out of 5     90 ratings  ₹2,849.00
# 149  4.3 out of 5  3,354 ratings  ₹6,349.00
#
#                                        Return/Exchange  Expected Delivery  \
# 0    https://www.amazon.in/Kadence-Slowhand-Premium...     Sunday, Dec 19
# 1    https://www.amazon.in/Kadence-Frontier-Acousti...     Sunday, Dec 19
# 2    https://www.amazon.in/Juarez-Acoustic-Guitar-C...     Monday, Dec 20
# 3    https://www.amazon.in/Vault-ST1-Premium-Electr...     Monday, Dec 20
# 4    https://www.amazon.in/Intern-INT-38C-Acoustic-...     Sunday, Dec 19
# ..                                                 ...                ...
# 145  https://www.amazon.in/Yamaha-FS100C-Acoustic-G...     Friday, Dec 17
# 146  https://www.amazon.in/LAVINGSTON-Givson-Specia...    Tuesday, Dec 21
# 147  https://www.amazon.in/Medellin-Premium-Acousti...     Sunday, Dec 19
# 148  https://www.amazon.in/Blueberry-Acoustic-Guita...  Wednesday, Dec 22
# 149  https://www.amazon.in/Martin-Smith-W-101-N-PK-...     Monday, Dec 20
#
#     Availability                                       Product URLs  \
# 0      In stock.  https://www.amazon.in/Kadence-Slowhand-Premium...
# 1      In stock.  https://www.amazon.in/Kadence-Frontier-Acousti...
# 2      In stock.  https://www.amazon.in/Juarez-Acoustic-Guitar-C...
# 3      In stock.  https://www.amazon.in/Vault-ST1-Premium-Electr...
# 4      In stock.  https://www.amazon.in/Intern-INT-38C-Acoustic-...
# ..           ...                                                ...
# 145    In stock.  https://www.amazon.in/Yamaha-FS100C-Acoustic-G...
# 146    In stock.  https://www.amazon.in/LAVINGSTON-Givson-Specia...
# 147    In stock.  https://www.amazon.in/Medellin-Premium-Acousti...
# 148    In stock.  https://www.amazon.in/Blueberry-Acoustic-Guita...
# 149    In stock.  https://www.amazon.in/Martin-Smith-W-101-N-PK-...
#
#                                          Other Details
# 0    ACOUSTIC-ELECTRIC GUITAR: Kadence Slowhand sem...
# 1    ★ Design - The High Gloss finish, Simple head ...
# 2    Jumbo Design, 38 Inch Acoustic Steel String Gu...
# 3    Sycamore Body, Maple neck, Rosewood fretboard,...
# 4    Great looks with an innovative design to produ...
# ..                                                 ...
# 145              Quality and tone, Number of Frets: 21
# 146  6-Strings, Acoustic Guitar , Right-Handed, red...
# 147  Perfect beginner guitar: Specially designed fo...
# 148                                      Used Material
# 149                       Steel strung full scale neck
#
# [150 rows x 10 columns]

# %%
item_df.to_csv(r"C:\Users\Neeraj Kumar\Desktop\Web Scrapping\item_details_from_amazon.csv", index=False)

# %% [markdown]
# # Question 3

# %%
# obtaining the web page details with the given url
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
url='https://images.google.com/'
urls = []    # empty list for image urls to download
data = []    # empty list for storing data
search_item = ["Fruits", "Cars", "Machine Learning"]
for item in search_item:
    driver.get(url)  # performing a Google search for our selected items
    time.sleep(3)
    search_bar = driver.find_element_by_tag_name("input")     # finding search bar on Google page   
    search_bar.send_keys(str(item))      # send search item list    
    search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click() # now we will click on search button
# Out:
# <ipython-input-20-4c91988bec78>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# <ipython-input-20-4c91988bec78>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_tag_name("input")     # finding search bar on Google page
# <ipython-input-20-4c91988bec78>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button =driver.find_element_by_xpath("//button[@class='Tg7LZd']").click() # now we will click on search button

# %%
for _ in range(500):
    driver.execute_script("window.scrollBy(0,100)")        
    imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
img_url = []
for image in imgs:
    source = image.get_attribute('src')
    if source is not None:
            if(source[0:4] == 'http'):
                img_url.append(source)
for i in img_url[:100]:      # getting only 100 images each
    urls.append(i)
for i in range(len(urls)):
    if i >= 300:
        break
    print("Obtaining {0} of {1} images".format(i, 300))
    response=requests.get(urls[i])
    file = open(r"C:\Users\Neeraj Kumar\Desktop\Web Scrapping\images"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# <ipython-input-29-f499c538e523>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   imgs = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
# Obtaining 0 of 300 images
# Obtaining 1 of 300 images
# Obtaining 2 of 300 images
# Obtaining 3 of 300 images
# Obtaining 4 of 300 images
# Obtaining 5 of 300 images
# Obtaining 6 of 300 images
# Obtaining 7 of 300 images
# Obtaining 8 of 300 images
# Obtaining 9 of 300 images
# Obtaining 10 of 300 images
# Obtaining 11 of 300 images
# Obtaining 12 of 300 images
# Obtaining 13 of 300 images
# Obtaining 14 of 300 images
# Obtaining 15 of 300 images
# Obtaining 16 of 300 images
# Obtaining 17 of 300 images
# Obtaining 18 of 300 images
# Obtaining 19 of 300 images
# Obtaining 20 of 300 images
# Obtaining 21 of 300 images
# Obtaining 22 of 300 images
# Obtaining 23 of 300 images
# Obtaining 24 of 300 images
# Obtaining 25 of 300 images
# Obtaining 26 of 300 images
# Obtaining 27 of 300 images
# Obtaining 28 of 300 images
# Obtaining 29 of 300 images
# Obtaining 30 of 300 images
# Obtaining 31 of 300 images
# Obtaining 32 of 300 images
# Obtaining 33 of 300 images
# Obtaining 34 of 300 images
# Obtaining 35 of 300 images
# Obtaining 36 of 300 images
# Obtaining 37 of 300 images
# Obtaining 38 of 300 images
# Obtaining 39 of 300 images
# Obtaining 40 of 300 images
# Obtaining 41 of 300 images
# Obtaining 42 of 300 images
# Obtaining 43 of 300 images
# Obtaining 44 of 300 images
# Obtaining 45 of 300 images
# Obtaining 46 of 300 images
# Obtaining 47 of 300 images
# Obtaining 48 of 300 images
# Obtaining 49 of 300 images
# Obtaining 50 of 300 images
# Obtaining 51 of 300 images
# Obtaining 52 of 300 images
# Obtaining 53 of 300 images
# Obtaining 54 of 300 images
# Obtaining 55 of 300 images
# Obtaining 56 of 300 images
# Obtaining 57 of 300 images
# Obtaining 58 of 300 images
# Obtaining 59 of 300 images
# Obtaining 60 of 300 images
# Obtaining 61 of 300 images
# Obtaining 62 of 300 images
# Obtaining 63 of 300 images
# Obtaining 64 of 300 images
# Obtaining 65 of 300 images
# Obtaining 66 of 300 images
# Obtaining 67 of 300 images
# Obtaining 68 of 300 images
# Obtaining 69 of 300 images
# Obtaining 70 of 300 images
# Obtaining 71 of 300 images
# Obtaining 72 of 300 images
# Obtaining 73 of 300 images
# Obtaining 74 of 300 images
# Obtaining 75 of 300 images
# Obtaining 76 of 300 images
# Obtaining 77 of 300 images
# Obtaining 78 of 300 images
# Obtaining 79 of 300 images
# Obtaining 80 of 300 images
# Obtaining 81 of 300 images
# Obtaining 82 of 300 images
# Obtaining 83 of 300 images
# Obtaining 84 of 300 images
# Obtaining 85 of 300 images
# Obtaining 86 of 300 images
# Obtaining 87 of 300 images
# Obtaining 88 of 300 images
# Obtaining 89 of 300 images
# Obtaining 90 of 300 images
# Obtaining 91 of 300 images
# Obtaining 92 of 300 images
# Obtaining 93 of 300 images
# Obtaining 94 of 300 images
# Obtaining 95 of 300 images
# Obtaining 96 of 300 images
# Obtaining 97 of 300 images
# Obtaining 98 of 300 images
# Obtaining 99 of 300 images
# Obtaining 100 of 300 images
# Obtaining 101 of 300 images
# Obtaining 102 of 300 images
# Obtaining 103 of 300 images
# Obtaining 104 of 300 images
# Obtaining 105 of 300 images
# Obtaining 106 of 300 images
# Obtaining 107 of 300 images
# Obtaining 108 of 300 images
# Obtaining 109 of 300 images
# Obtaining 110 of 300 images
# Obtaining 111 of 300 images
# Obtaining 112 of 300 images
# Obtaining 113 of 300 images
# Obtaining 114 of 300 images
# Obtaining 115 of 300 images
# Obtaining 116 of 300 images
# Obtaining 117 of 300 images
# Obtaining 118 of 300 images
# Obtaining 119 of 300 images
# Obtaining 120 of 300 images
# Obtaining 121 of 300 images
# Obtaining 122 of 300 images
# Obtaining 123 of 300 images
# Obtaining 124 of 300 images
# Obtaining 125 of 300 images
# Obtaining 126 of 300 images
# Obtaining 127 of 300 images
# Obtaining 128 of 300 images
# Obtaining 129 of 300 images
# Obtaining 130 of 300 images
# Obtaining 131 of 300 images
# Obtaining 132 of 300 images
# Obtaining 133 of 300 images
# Obtaining 134 of 300 images
# Obtaining 135 of 300 images
# Obtaining 136 of 300 images
# Obtaining 137 of 300 images
# Obtaining 138 of 300 images
# Obtaining 139 of 300 images
# Obtaining 140 of 300 images
# Obtaining 141 of 300 images
# Obtaining 142 of 300 images
# Obtaining 143 of 300 images
# Obtaining 144 of 300 images
# Obtaining 145 of 300 images
# Obtaining 146 of 300 images
# Obtaining 147 of 300 images
# Obtaining 148 of 300 images
# Obtaining 149 of 300 images
# Obtaining 150 of 300 images
# Obtaining 151 of 300 images
# Obtaining 152 of 300 images
# Obtaining 153 of 300 images
# Obtaining 154 of 300 images
# Obtaining 155 of 300 images
# Obtaining 156 of 300 images
# Obtaining 157 of 300 images
# Obtaining 158 of 300 images
# Obtaining 159 of 300 images
# Obtaining 160 of 300 images
# Obtaining 161 of 300 images
# Obtaining 162 of 300 images
# Obtaining 163 of 300 images
# Obtaining 164 of 300 images
# Obtaining 165 of 300 images
# Obtaining 166 of 300 images
# Obtaining 167 of 300 images
# Obtaining 168 of 300 images
# Obtaining 169 of 300 images
# Obtaining 170 of 300 images
# Obtaining 171 of 300 images
# Obtaining 172 of 300 images
# Obtaining 173 of 300 images
# Obtaining 174 of 300 images
# Obtaining 175 of 300 images
# Obtaining 176 of 300 images
# Obtaining 177 of 300 images
# Obtaining 178 of 300 images
# Obtaining 179 of 300 images
# Obtaining 180 of 300 images
# Obtaining 181 of 300 images
# Obtaining 182 of 300 images
# Obtaining 183 of 300 images
# Obtaining 184 of 300 images
# Obtaining 185 of 300 images
# Obtaining 186 of 300 images
# Obtaining 187 of 300 images
# Obtaining 188 of 300 images
# Obtaining 189 of 300 images
# Obtaining 190 of 300 images
# Obtaining 191 of 300 images
# Obtaining 192 of 300 images
# Obtaining 193 of 300 images
# Obtaining 194 of 300 images
# Obtaining 195 of 300 images
# Obtaining 196 of 300 images
# Obtaining 197 of 300 images
# Obtaining 198 of 300 images
# Obtaining 199 of 300 images
# Obtaining 200 of 300 images

# %% [markdown]
# # Question 4

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# getting the web page with the provided url
url = "https://www.flipkart.com/"
# Out:
# <ipython-input-43-fa5c5df0c901>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
driver.get(url)
time.sleep(3)  # waiting for 3 seconds here
click_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
# Out:
# <ipython-input-44-a0f5567b4b92>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()

# %%
#giving inputs to search bar
search_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
search_bar.send_keys("Smartphones")
search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn.click()
time.sleep(5)
# Out:
# <ipython-input-45-528738ab8bf0>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
# <ipython-input-45-528738ab8bf0>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# %%
# fetching urls of every smartphone on Flipkart
urls = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

# getting the required data inside the empty lists
brand_names = []
name = []
color = []
RAM = []
storage = []
prim_cam = []
sec_cam = []
Display_size = []
display_resolution = []
processor = []
processor_core = []
battery_cap = []
prices = []
product_url = []
# fetching battery capacity
for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
    try:
        bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
        battery_cap.append(bat_cap.text)
    except NoSuchElementException:
        battery_cap.append('-')
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    # fetching brand names
    try:
        br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        brand_names.append(br_name.text.replace('Mobiles',''))
    except NoSuchElementException:
        brand_names.append('-')
    # fetching the smartphone names
    try:
        smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
        name.append(smt_name.text)
    except NoSuchElementException:
        name.append('-')
    
    # fetching colors of smartphone
    try:
        clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    time.sleep(2)
    # getting the read more button
    try:
        read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        pass
    time.sleep(3)
    
    # fetching the display size
    try:
        disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
        Display_size.append(disp_size.text)
    except NoSuchElementException:
        Display_size.append
        
    # fetching the display resolution
    try:
        disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
        display_resolution.append(disp_res.text)
    except NoSuchElementException:
        display_resolution.append('-')
        
    # fetching the processor information
    try:
        pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append('-')
        
    # fetching the processor and number of core details
    try:
        pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
        processor_core.append(pro_core.text)
    except NoSuchElementException:
        processor_core.append('-')
        
    # fetching the storage/ROM details
    try:
        rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
        storage.append(rom.text)
    except NoSuchElementException:
        storage.append('-')
        
    # fetching the RAM information
    try:
        ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(2)
    
    # fetching the primary camera information
    try:
        p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
        prim_cam.append(p_cam.text)
    except NoSuchElementException:
        prim_cam.append('-')
        
    # fetching the secondary camera information
    try:
        s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
        sec_cam.append(s_cam.text)
    except NoSuchElementException:
        sec_cam.append('-')        
    # fetching the price of the smartphone
    try:
        price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        prices.append(price.text.replace('₹','Rs. '))
    except NoSuchElementException:
        prices.append('-')
# Out:
# <ipython-input-46-41a29048b126>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
# <ipython-input-46-41a29048b126>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
# <ipython-input-46-41a29048b126>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
# <ipython-input-46-41a29048b126>:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
# <ipython-input-46-41a29048b126>:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
# <ipython-input-46-41a29048b126>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
# <ipython-input-46-41a29048b126>:54: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
# <ipython-input-46-41a29048b126>:61: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
# <ipython-input-46-41a29048b126>:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
# <ipython-input-46-41a29048b126>:75: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
# <ipython-input-46-41a29048b126>:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
# <ipython-input-46-41a29048b126>:89: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
# <ipython-input-46-41a29048b126>:96: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
# <ipython-input-46-41a29048b126>:104: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
# <ipython-input-46-41a29048b126>:111: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
# <ipython-input-46-41a29048b126>:117: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")

# %%
# creating a dataframe now with the obtainined details
data = list(zip(brand_names,name,color,RAM,storage,prim_cam,sec_cam,Display_size,display_resolution,processor,
                processor_core,battery_cap,prices,urls))
df = pd.DataFrame(data, columns = ["Brand Name","Smartphone Name","Color","RAM","Storage/ROM","Primary Camera",
                                   "Secondary Camera","Display Size","Display Resolution","Processor","Processor-Core",
                                   "Battery Capacity","Price","Product Url"])
df
# Out:
#    Brand Name                                    Smartphone Name  \
# 0           -        realme C25Y (Metal Grey, 64 GB)  (4 GB RAM)
# 1           -      realme C25Y (Glacier Blue, 64 GB)  (4 GB RAM)
# 2           -        realme C21Y (Cross Blue, 64 GB)  (4 GB RAM)
# 3           -              I Kall K260 (Blue, 16 GB)  (2 GB RAM)
# 4           -        realme C21Y (Cross Blue, 32 GB)  (3 GB RAM)
# 5           -       realme C21Y (Cross Black, 64 GB)  (4 GB RAM)
# 6           -       realme C21Y (Cross Black, 32 GB)  (3 GB RAM)
# 7           -  realme Narzo 50i (Carbon Black, 32 GB)  (2 GB ...
# 8           -   realme Narzo 50i (Mint Green, 32 GB)  (2 GB RAM)
# 9           -   realme Narzo 50i (Mint Green, 64 GB)  (4 GB RAM)
# 10          -         REDMI 9i (Nature Green, 64 GB)  (4 GB RAM)
# 11          -  realme Narzo 50A (Oxygen Blue, 64 GB)  (4 GB RAM)
# 12          -  realme Narzo 50A (Oxygen Green, 128 GB)  (4 GB...
# 13          -  realme Narzo 50A (Oxygen Blue, 128 GB)  (4 GB ...
# 14          -             REDMI 9i (Sea Blue, 64 GB)  (4 GB RAM)
# 15          -  realme Narzo 50A (Oxygen Green, 64 GB)  (4 GB ...
# 16          -  realme Narzo 50i (Carbon Black, 64 GB)  (4 GB ...
# 17          -        realme 8i (Space Black, 128 GB)  (6 GB RAM)
# 18          -         realme 8i (Space Black, 64 GB)  (4 GB RAM)
# 19          -       realme C25Y (Metal Grey, 128 GB)  (4 GB RAM)
# 20          -       realme C25_Y (Metal Grey, 64 GB)  (4 GB RAM)
# 21          -   REDMI 9i Sport (Carbon Black, 64 GB)  (4 GB RAM)
# 22          -     realme C25Y (Glacier Blue, 128 GB)  (4 GB RAM)
# 23          -        realme 8i (Space Purple, 64 GB)  (4 GB RAM)
#
#            Color   RAM Storage/ROM    Primary Camera   Secondary Camera  \
# 0     Metal Grey  4 GB       64 GB  50MP + 2MP + 2MP   8MP Front Camera
# 1   Glacier Blue  4 GB       64 GB  50MP + 2MP + 2MP   8MP Front Camera
# 2     Cross Blue  4 GB       64 GB  13MP + 2MP + 2MP   5MP Front Camera
# 3           Blue  2 GB       16 GB   8MP Rear Camera   5MP Front Camera
# 4     Cross Blue  3 GB       32 GB  13MP + 2MP + 2MP   5MP Front Camera
# 5    Cross Black  4 GB       64 GB  13MP + 2MP + 2MP   5MP Front Camera
# 6    Cross Black  3 GB       32 GB  13MP + 2MP + 2MP   5MP Front Camera
# 7   Carbon Black  2 GB       32 GB   8MP Rear Camera   5MP Front Camera
# 8     Mint Green  2 GB       32 GB   8MP Rear Camera   5MP Front Camera
# 9     Mint Green  4 GB       64 GB   8MP Rear Camera   5MP Front Camera
# 10  Nature Green  4 GB       64 GB  13MP Rear Camera   5MP Front Camera
# 11   Oxygen Blue  4 GB       64 GB  50MP + 2MP + 2MP   8MP Front Camera
# 12  Oxygen Green  4 GB      128 GB  50MP + 2MP + 2MP   8MP Front Camera
# 13   Oxygen Blue  4 GB      128 GB  50MP + 2MP + 2MP   8MP Front Camera
# 14      Sea Blue  4 GB       64 GB  13MP Rear Camera   5MP Front Camera
# 15  Oxygen Green  4 GB       64 GB  50MP + 2MP + 2MP   8MP Front Camera
# 16  Carbon Black  4 GB       64 GB   8MP Rear Camera   5MP Front Camera
# 17   Space Black  6 GB      128 GB  50MP + 2MP + 2MP  16MP Front Camera
# 18   Space Black  4 GB       64 GB  50MP + 2MP + 2MP  16MP Front Camera
# 19    Metal Grey  4 GB      128 GB  50MP + 2MP + 2MP   8MP Front Camera
# 20    Metal Grey  4 GB       64 GB  50MP + 2MP + 2MP   8MP Front Camera
# 21  Carbon Black  4 GB       64 GB  13MP Rear Camera   5MP Front Camera
# 22  Glacier Blue  4 GB      128 GB  50MP + 2MP + 2MP   8MP Front Camera
# 23  Space Purple  4 GB       64 GB  50MP + 2MP + 2MP  16MP Front Camera
#
#             Display Size  Display Resolution              Processor  \
# 0    16.51 cm (6.5 inch)   1600 x 720 Pixels  Unisoc T610 Octa Core
# 1    16.51 cm (6.5 inch)   1600 x 720 Pixels  Unisoc T610 Octa Core
# 2    16.51 cm (6.5 inch)   1600 x 720 Pixels            Unisoc T610
# 3   13.84 cm (5.45 inch)             480*960              Quad Core
# 4    16.51 cm (6.5 inch)   1600 x 720 Pixels            Unisoc T610
# 5    16.51 cm (6.5 inch)   1600 x 720 Pixels            Unisoc T610
# 6    16.51 cm (6.5 inch)   1600 x 720 Pixels            Unisoc T610
# 7    16.51 cm (6.5 inch)   1600 x 720 Pixels                SC9863A
# 8    16.51 cm (6.5 inch)   1600 x 720 Pixels                SC9863A
# 9    16.51 cm (6.5 inch)   1600 x 720 Pixels                SC9863A
# 10  16.59 cm (6.53 inch)   1600 x 720 Pixels     MediaTek Helio G25
# 11   16.51 cm (6.5 inch)   1600 x 720 Pixels     MediaTek Helio G85
# 12   16.51 cm (6.5 inch)   1600 x 720 Pixels     MediaTek Helio G85
# 13   16.51 cm (6.5 inch)   1600 x 720 Pixels     MediaTek Helio G85
# 14  16.59 cm (6.53 inch)   1600 x 720 Pixels     MediaTek Helio G25
# 15   16.51 cm (6.5 inch)   1600 x 720 Pixels     MediaTek Helio G85
# 16   16.51 cm (6.5 inch)   1600 x 720 Pixels                SC9863A
# 17   16.76 cm (6.6 inch)  2412 x 1080 Pixels     MediaTek Helio G96
# 18   16.76 cm (6.6 inch)  2412 x 1080 Pixels     MediaTek Helio G96
# 19   16.51 cm (6.5 inch)   1600 x 720 Pixels  Unisoc T610 Octa Core
# 20   16.51 cm (6.5 inch)   1600 x 720 Pixels            Unisoc T618
# 21  16.59 cm (6.53 inch)   1600 x 720 Pixels     MediaTek Helio G25
# 22   16.51 cm (6.5 inch)   1600 x 720 Pixels  Unisoc T610 Octa Core
# 23   16.76 cm (6.6 inch)  2412 x 1080 Pixels     MediaTek Helio G96
#
#    Processor-Core  Battery Capacity       Price  \
# 0       Octa Core  5000 mAh Battery  Rs. 10,999
# 1       Octa Core  5000 mAh Battery  Rs. 10,999
# 2       Octa Core  5000 mAh Battery   Rs. 9,999
# 3         1.3 GHz  5000 mAh Battery   Rs. 4,499
# 4       Octa Core  5000 mAh Battery   Rs. 8,999
# 5       Octa Core  5000 mAh Battery   Rs. 9,999
# 6       Octa Core  5000 mAh Battery   Rs. 8,999
# 7       Octa Core  5000 mAh Battery   Rs. 7,499
# 8       Octa Core  5000 mAh Battery   Rs. 7,499
# 9       Octa Core  5000 mAh Battery   Rs. 8,999
# 10      Octa Core  5000 mAh Battery   Rs. 8,799
# 11      Octa Core  5000 mAh Battery  Rs. 11,499
# 12      Octa Core  5000 mAh Battery  Rs. 12,499
# 13      Octa Core  5000 mAh Battery  Rs. 12,499
# 14      Octa Core  5000 mAh Battery   Rs. 8,799
# 15      Octa Core  5000 mAh Battery  Rs. 11,499
# 16      Octa Core  5000 mAh Battery   Rs. 8,999
# 17      Octa Core  5000 mAh Battery  Rs. 15,999
# 18      Octa Core  5000 mAh Battery  Rs. 13,999
# 19      Octa Core  5000 mAh Battery  Rs. 11,999
# 20      Octa Core  5000 mAh Battery  Rs. 10,999
# 21      Octa Core  5000 mAh Battery   Rs. 8,799
# 22      Octa Core  5000 mAh Battery  Rs. 11,999
# 23      Octa Core  5000 mAh Battery  Rs. 13,999
#
#                                           Product Url
# 0   https://www.flipkart.com/realme-c25y-metal-gre...
# 1   https://www.flipkart.com/realme-c25y-glacier-b...
# 2   https://www.flipkart.com/realme-c21y-cross-blu...
# 3   https://www.flipkart.com/kall-k260-blue-16-gb/...
# 4   https://www.flipkart.com/realme-c21y-cross-blu...
# 5   https://www.flipkart.com/realme-c21y-cross-bla...
# 6   https://www.flipkart.com/realme-c21y-cross-bla...
# 7   https://www.flipkart.com/realme-narzo-50i-carb...
# 8   https://www.flipkart.com/realme-narzo-50i-mint...
# 9   https://www.flipkart.com/realme-narzo-50i-mint...
# 10  https://www.flipkart.com/redmi-9i-nature-green...
# 11  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 12  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 13  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 14  https://www.flipkart.com/redmi-9i-sea-blue-64-...
# 15  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 16  https://www.flipkart.com/realme-narzo-50i-carb...
# 17  https://www.flipkart.com/realme-8i-space-black...
# 18  https://www.flipkart.com/realme-8i-space-black...
# 19  https://www.flipkart.com/realme-c25y-metal-gre...
# 20  https://www.flipkart.com/realme-c25-y-metal-gr...
# 21  https://www.flipkart.com/redmi-9i-sport-carbon...
# 22  https://www.flipkart.com/realme-c25y-glacier-b...
# 23  https://www.flipkart.com/realme-8i-space-purpl...

# %%
# exporting the above dataframe in csv format
df.to_csv(r"C:\Users\Neeraj Kumar\Desktop\Web Scrapping\smartphone_details_from_flipkart.csv", index=False)

# %% [markdown]
# # Question 5

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
url="https://www.google.co.in/maps"
driver.get(url)
srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  # getting the search bar
place = str(input("Enter the place name which you want to search on Google Maps: "))  # taking input from user to search for location
srch_box.send_keys(place)    
submit = driver.find_element_by_class_name("nhb85d-BIqFsb")
submit.click()  # clicking on the search button
# Out:
# <ipython-input-49-fb6c90e20c24>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# <ipython-input-49-fb6c90e20c24>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  # getting the search bar
# Enter the place name which you want to search on Google Maps: Trichy
# <ipython-input-49-fb6c90e20c24>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   submit = driver.find_element_by_class_name("nhb85d-BIqFsb")

# %%
current_url = driver.current_url   # coordinates are presents in the URL so fetching current url

# %%
import re

try:
    lat = re.findall('(\d+(\.\d*)?)', current_url)[0]   # fetching the latitude data
    lon = re.findall('(\d+(\.\d*)?)', current_url)[1]  # fetching the longitude data
    print("Geospatial Coordinates for", place + " on Google Maps are: ")
    print("Latitude  :", lat[0])
    print("Longitude :", lon[0])
    
except Exception as e:
    print("Error: ", str(e))
# Out:
# Geospatial Coordinates for Trichy on Google Maps are:
# Latitude  : 10.8160054
# Longitude : 78.6189864

# %% [markdown]
# # Question 6

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
driver.get('https://trak.in/')
time.sleep(2)

driver.get(driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href'))
# Out:
# <ipython-input-52-1d4110b4051f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# <ipython-input-52-1d4110b4051f>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.get(driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href'))

# %%
#creating the empty list 
date=[]
name=[]
industry=[]
sub=[]
city=[]
investor=[]
inv_type=[]
amount=[]
#scrapping for date
for i in driver.find_elements_by_xpath('//td[@class="column-2"]'):
    date.append(i.text)

#scrapping for name
for i in driver.find_elements_by_xpath('//td[@class="column-3"]'):
    name.append(i.text)

#scrapping for industry    
for i in driver.find_elements_by_xpath('//td[@class="column-4"]'):
    industry.append(i.text)

#scrapping for sub industry
for i in driver.find_elements_by_xpath('//td[@class="column-5"]'):
    sub.append(i.text)

#scrapping for city    
for i in driver.find_elements_by_xpath('//td[@class="column-6"]'):
    city.append(i.text)
#scrapping for investor
for i in driver.find_elements_by_xpath('//td[@class="column-7"]'):
    investor.append(i.text)

#scrapping for investor type    
for i in driver.find_elements_by_xpath('//td[@class="column-8"]'):
    inv_type.append(i.text)

#scrapping for amount
for i in driver.find_elements_by_xpath('//td[@class="column-9"]'):
    amount.append(i.text)
# Out:
# <ipython-input-53-85bb522fcbac>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-2"]'):
# <ipython-input-53-85bb522fcbac>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-3"]'):
# <ipython-input-53-85bb522fcbac>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-4"]'):
# <ipython-input-53-85bb522fcbac>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-5"]'):
# <ipython-input-53-85bb522fcbac>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-6"]'):
# <ipython-input-53-85bb522fcbac>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-7"]'):
# <ipython-input-53-85bb522fcbac>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-8"]'):
# <ipython-input-53-85bb522fcbac>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-9"]'):

# %%
#creating the dataframe for Jul-Sep
Funding={'Date':date,'Name':name,'Industry/Vertica':industry,'Sub-vertical':sub,'City':city,'Investor':investor,
        'Investment Type':inv_type,'Amount':amount}
Funding=pd.DataFrame(data=Funding)
Funding[55:85]
# Out:
#           Date                       Name  \
# 55  08/09/2020                     Byju’s
# 56  12/09/2020                  mCaffeine
# 57  09/09/2020                     Qshala
# 58  02/09/2020                      Winzo
# 59  09/09/2020                Hippo Video
# 60  07/09/2020                    Melorra
# 61  07/09/2020                        1mg
# 62  31/08/2020                      mfine
# 63  31/08/2020                       Apna
# 64  03/09/2020                    Railofy
# 65  15/08/2020                     Practo
# 66  13/08/2020                    Medlife
# 67  13/08/2020                  HungerBox
# 68  04/08/2020                      Dunzo
# 69  11/08/2020                   Terra.do
# 70  12/08/2020                  Classplus
# 71  14/08/2020                       Niyo
# 72  10/08/2020                  ZestMoney
# 73  07/08/2020                FreshToHome
# 74  13/08/2020                    Eduvanz
# 75  15/07/2020                   Flipkart
# 76  16/07/2020                    Vedantu
# 77  16/07/2020                       Crio
# 78  14/07/2020                    goDutch
# 79  13/07/2020                   Mystifly
# 80  09/07/2020               JetSynthesys
# 81  10/07/2020                   gigIndia
# 82  15/07/2020                  PumPumPum
# 83  14/07/2020                       FLYX
# 84  13/07/2020  Open Appliances Pvt. Ltd.
#
#                           Industry/Vertica  \
# 55                                 EduTech
# 56                           Personal Care
# 57                                 EduTech
# 58                           Online Gaming
# 59  Video Customer Experience(CX) Platform
# 60                              E-commerce
# 61                              E-commerce
# 62                              HealthTech
# 63                         Human Resources
# 64                          Transportation
# 65                              HealthTech
# 66                              E-commerce
# 67                                FoodTech
# 68                   Hyper-local Logistics
# 69                                 EduTech
# 70                                 EduTech
# 71                                 FinTech
# 72                                 FinTech
# 73                              E-commerce
# 74                                 FinTech
# 75                              E-commerce
# 76                                 EduTech
# 77                                 EduTech
# 78                                 FinTech
# 79                     Airfare Marketplace
# 80                Gaming and Entertainment
# 81                             Marketplace
# 82                       Automotive Rental
# 83                              OTT Player
# 84                  Information Technology
#
#                                          Sub-vertical  \
# 55                                    Online Tutoring
# 56                                Skincare & Haircare
# 57                 Online Curiosity Platform for Kids
# 58                                      Online Gaming
# 59             Video Customer Experience(CX) Platform
# 60                               Online Jewelry Store
# 61                                    Online Pharmacy
# 62                      On-Demand Healthcare Services
# 63                               Recruitment Platform
# 64                       WL & RAC protection platform
# 65                           Health care and Wellness
# 66                                    Online Pharmacy
# 67                       Online Food Delivery Service
# 68                           Online Delivery Services
# 69                  Online Climate School, E-learning
# 70                        E-learning, Online Tutoring
# 71                                 Financial Services
# 72                                 Financial Services
# 73                                      Food Delivery
# 74                                 Financial Services
# 75                                         E-commerce
# 76                                    Online Tutoring
# 77                   Learning Platform for Developers
# 78                                     Group Payments
# 79  Ticketing, Airline Retailing, and Post-Ticketi...
# 80                           Gaming and Entertainment
# 81                          Crowd Sourcing, Freelance
# 82                          Used Car-leasing platform
# 83                           Streaming Social Network
# 84              Internet-of-Things Security Solutions
#
#                                           City  \
# 55                                   Bangalore
# 56                                      Mumbai
# 57                                   Bangalore
# 58                                   New Delhi
# 59  Newark, Delaware, United States of Amercia
# 60                                   Bangalore
# 61                                     Gurgaon
# 62                                   Bangalore
# 63                                   Bangalore
# 64                                      Mumbai
# 65                                   Bangalore
# 66                                   Bangalore
# 67                                   Bangalore
# 68                                   Bangalore
# 69                       Stanford, California,
# 70                                       Noida
# 71                                   Bangalore
# 72                                   Bangalore
# 73                                   Bangalore
# 74                                      Mumbai
# 75                                   Bangalore
# 76                                   Bangalore
# 77                                   Bangalore
# 78                                      Mumbai
# 79                     Singapore and Bangalore
# 80                                        Pune
# 81                                        Pune
# 82                                     Gurgaon
# 83                          New York and Delhi
# 84                                   Bangalore
#
#                                              Investor         Investment Type  \
# 55  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 56  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 57                                 Rainmatter Capital                   Angel
# 58  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 59  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 60                         Shadow Holdings, Lightbox.          Debt Financing
# 61         Gaja Capital, Tata Capital, Partners Group             In Progress
# 62                                   Caretech Pte Inc                Series B
# 63         Lightspeed India and Sequoia Capital India                Series A
# 64                                  Chiratae Ventures                    Seed
# 65                                        A1A Company                Series F
# 66         Prasid Uno Family Trust and SC Credit Fund
# 67  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 68                                   Existing Backers             In Progress
# 69  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 70                                        Falcon Edge             In Progress
# 71                                Niyo Solutions Inc.
# 72                            Primrose Hills Ventures
# 73                                     Ascent Capital                 Venture
# 74                              Sequoia India, Unitus                Series A
# 75                                        Walmart Inc                     M&A
# 76                                  Coatue Management                Series D
# 77                                        021 Capital            pre-Series A
# 78  Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 79                                   Recruit Co. Ltd.            pre-Series B
# 80           Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 81       Incubate Fund India and Beyond Next Ventures            pre-Series A
# 82                           Early Adapters Syndicate                    Seed
# 83              Raj Mishra, founder of AIT Global Inc                pre-Seed
# 84                             Unicorn India Ventures  Venture-Series Unknown
#
#              Amount
# 55      500,000,000
# 56        3,000,000
# 57          370,000
# 58       15,500,000
# 59        4,500,000
# 60   upto 8,900,000
# 61      100,000,000
# 62        5,400,000
# 63        8,000,000
# 64          950,000
# 65       32,000,000
# 66       23,000,000
# 67        1,560,000
# 68       30,000,000
# 69        1,400,000
# 70  upto 15,000,000
# 71        6,000,000
# 72       10,670,000
# 73       16,200,000
# 74        5,000,000
# 75    1,200,000,000
# 76      100,000,000
# 77          934,160
# 78        1,700,000
# 79        3,300,000
# 80          400,000
# 81          974,200
# 82          292,800
# 83          200,000
# 84          500,000

# %% [markdown]
# # Question 7

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# getting the web page with given url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(3)
# Out:
# <ipython-input-55-278b6d1efe6b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
# now we will search for best gaming laptops
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)
# Out:
# <ipython-input-56-329cc94fa2c8>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()

# %%
# creating empty lists to store all gaming laptop information
lap_name = []
op_stm = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_processor = []
prices = []
# fetching the laptop names
name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    lap_name.append(i.text)
    
# fetching information related to operating system
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        op_stm.append(i.text)
except NoSuchElementException:
    pass

# fetching information for display
try:
    disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in disp:
        display.append(i.text)
except NoSuchElementException:
    pass
# fetching information for processor
try:
    pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in pro:
        processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for memory
try:
    mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in mem:
        memory.append(i.text)
except NoSuchElementException:
    pass

# fetching information for weight
try:
    wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in wgt:
        weight.append(i.text)
except NoSuchElementException:
    pass
# fetching information for dimensions
try:
    dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dim:
        dimensions.append(i.text)
except NoSuchElementException:
    pass

# fetching information for graphic processor
try:
    g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in g_pro:
        graph_processor.append(i.text)
except NoSuchElementException:
    pass
# fetching information for price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for i in price:
        prices.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass
# Out:
# <ipython-input-57-594d77f4d262>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
# <ipython-input-57-594d77f4d262>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
# <ipython-input-57-594d77f4d262>:26: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
# <ipython-input-57-594d77f4d262>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
# <ipython-input-57-594d77f4d262>:41: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
# <ipython-input-57-594d77f4d262>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
# <ipython-input-57-594d77f4d262>:56: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
# <ipython-input-57-594d77f4d262>:64: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
# <ipython-input-57-594d77f4d262>:71: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price = driver.find_elements_by_xpath("//td[@class='smprice']")

# %%
# now creating a dataframe from all the collected details
data = list(zip(lap_name,op_stm,display,processor,memory,weight,dimensions,graph_processor,prices))
df = pd.DataFrame(data, columns = ["Laptop Name","Operating System","Display","Processor","Memory",
                                   "Weight(Kg)","Dimensions","Graphic-Processor","Price"])
df
# Out:
#                                      Laptop Name Operating System  \
# 0                    Acer NITRO 5 Ryzen 9 (2021)       Windows 10
# 1  MSI Stealth 15M 11th Gen Core i7-11375H (2021       Windows 10
# 2   ASUS ROG Strix Scar 15 Ryzen 9-5900HX (2021)       Windows 10
# 3                          Alienware Area 51M R2  Windows 10 Home
# 4                               Alienware m15 R3  Windows 10 Home
# 5                         ASUS ROG Strix Scar 15  Windows 10 Home
# 6                          Asus ROG Zephyrus G14  Windows 10 Home
# 7                               Lenovo Legion 5i   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           Acer Aspire 7 gaming  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 x 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 x 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 x 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 x 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 x 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 x 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 x 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 x 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#                    Memory Weight(Kg)               Dimensions  \
# 0   1 TB HDD/16 GBGB DDR4        2.4       363.4 x 255 x 23.9
# 1   1 TB SSD/16 GBGB DDR4        1.7      358.3 x 248 x 16.15
# 2   2 TB SSD/32 GBGB DDR4       2.30         354 x 259 x 22.6
# 3   1 TB SSD/16 GBGB DDR4        4.1   27.65 x 402.6 x 319.14
# 4   1 TB SSD/16 GBGB DDR4         NA                       NA
# 5   1 TB SSD/16 GBGB DDR4       2.30       35.4 x 25.9 x 2.26
# 6   1 TB SSD/16 GBGB DDR4       1.65        32.5 x 22.1 x 1.8
# 7   1 TB SSD/16 GBGB DDR4        2.3  363.06 x 259.61 x 23.57
# 8  512 GB SSD/4 GBGB DDR4        2.4  268.30 x 360.00 x 20.90
# 9  512 GB SSD/8 GBGB DDR4       2.15       2.29 x 36.3 x 25.4
#
#                Graphic-Processor        Price
# 0        NVIDIA GeForce RTX 3070  Rs  129,990
# 1        NVIDIA GeForce RTX 3060  Rs  134,990
# 2        NVIDIA GeForce RTX 3080  Rs  268,990
# 3        Intel® UHD Graphics 630  Rs  342,989
# 4                             NA  Rs  319,990
# 5      NVIDIA® GeForce RTX™ 3070  Rs  215,990
# 6        NVIDIA GeForce RTX 2060  Rs  164,990
# 7  NVIDIA® GeForce® GTX 1650 4GB   Rs  76,988
# 8  NVIDIA GeForce RTX 2070 Max-Q  Rs  185,000
# 9      NVIDIA® GeForce® GTX 1650   Rs  58,898

# %% [markdown]
# # Question 8

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# obtaining the web page with given url
url = 'https://www.forbes.com/'
driver.get(url)
time.sleep(3)
# Out:
# <ipython-input-59-633c523b10e8>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
# clicking on the hamburger option on the left side of the page
optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
optn.click()
time.sleep(1)
# Out:
# <ipython-input-60-40e96fe2453e>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")

# %%
# now clicking on the 'Billionaires' option
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)
# Out:
# <ipython-input-61-7eaf8cceac86>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")

# %%
# finally clicking on the 'World Billionaire' option after the mouse hover
world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)
# Out:
# <ipython-input-62-cafcee9439c8>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")

# %%
# fetching the rank
rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass

# fetching the names of the billionaires
names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass
# fetching the total net worth
net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass

# fetching the age of the billionaires
Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')
# fetching the citizenship of the billionaires
citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')
    
# fetching the source of incomes for the billionaires
source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
# fetching the industry in which the billionaires are prominent
industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
# Out:
# <ipython-input-63-dcf1e026f60c>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rnk = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-63-dcf1e026f60c>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//div[@class='personName']")
# <ipython-input-63-dcf1e026f60c>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
# <ipython-input-63-dcf1e026f60c>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age = driver.find_elements_by_xpath("//div[@class='age']")
# <ipython-input-63-dcf1e026f60c>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-63-dcf1e026f60c>:47: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src = driver.find_elements_by_xpath("//div[@class='source-column']")
# <ipython-input-63-dcf1e026f60c>:56: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath("//div[@class='category']")

# %%
# now creating a dataframe from all the collected information
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
df
# Out:
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# # Question 9

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# obtaining the web page with given url
url = "https://www.youtube.com/watch?v=mSxeQoJgPw0"
driver.get(url)
# Out:
# <ipython-input-65-f0d4dee8d8c6>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
# we are going to scroll through the comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,100)")

# %%
# creating empty lists to store the required information
comments = []
upvotes = []
times = []

# fetching all the comments
try:
    comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(5)
# fetching all the upvotes
try:
    up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    upvotes.append('-')
time.sleep(5)
# fetching all the time information indicating when the comment was made
try:
    timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    for i in timing:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(5)
# Out:
# <ipython-input-72-3a358fd3cd17>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
# <ipython-input-72-3a358fd3cd17>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
# <ipython-input-72-3a358fd3cd17>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]

# %%
# now we are creating a dataframe from the accumulated information
data = list(zip(comments,upvotes,times))
df = pd.DataFrame(data, columns = ["Comment","Upvotes","Published time"])
df
# Out:
#                                                Comment Upvotes Published time
# 0    Have you always wanted to see Bassjackers live...     141    2 years ago
# 1    a really great track and a good collab between...      44    5 years ago
# 2    Llevo años literalmente buscando esta canción ...      26     1 year ago
# 3    KSHMR is so amazing. He is the only DJ/Produce...     136    5 years ago
# 4             This is such an underrated song of KSHMR     149     1 year ago
# ..                                                 ...     ...            ...
# 495               man this is soon gonna be mainstream            5 years ago
# 496             Finally found this song after 2 months       1    3 years ago
# 497            Kshmr ur awsoooooooooooom u r like fire            3 years ago
# 498                Anybody know the name of that font?       8    5 years ago
# 499     Kshmr is the reason im still subbed to spinnin            5 years ago
#
# [500 rows x 3 columns]

# %% [markdown]
# # Question 10

# %%
driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')
# obtaining the web page from the given url
url = "https://www.hostelworld.com/"
driver.get(url)
# Out:
# <ipython-input-107-66bb1116721d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\Neeraj Kumar\Downloads\chromedriver_win32\chromedriver')

# %%
#entering the city name in search bar
driver.find_element_by_xpath("//input[@id='search-input-field']").send_keys('London')
button = driver.find_element_by_xpath("//div[@class='label']")
button.click()
# Out:
# <ipython-input-113-5954338797a4>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//input[@id='search-input-field']").send_keys('London')
# <ipython-input-113-5954338797a4>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath("//div[@class='label']")

# %%
search_button = driver.find_element_by_id('search-button')
search_button.click()
# Out:
# <ipython-input-114-18c62b26d0c5>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id('search-button')

# %%
# creating empty lists to collect the required information
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []
for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    
    # fetching hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        # fetching the distance from city centre    
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        
    # fetching the privates from price details
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
            
    # fetching the dorms from price information
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            # fetching all the facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
        
    # fetching the urls of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    # clicking on the show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    
    # fetching the ratings for the hostels
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
    # fetching the total reviews        
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        # fetching the overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
        
    # fetching the property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')
# Out:
# <ipython-input-115-19e758966db4>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
# <ipython-input-115-19e758966db4>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
# <ipython-input-115-19e758966db4>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
# <ipython-input-115-19e758966db4>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
# <ipython-input-115-19e758966db4>:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
# <ipython-input-115-19e758966db4>:41: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
# <ipython-input-115-19e758966db4>:43: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
# <ipython-input-115-19e758966db4>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
# <ipython-input-115-19e758966db4>:50: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
# <ipython-input-115-19e758966db4>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
# <ipython-input-115-19e758966db4>:67: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//a[@class='toggle-content']").click()
# <ipython-input-115-19e758966db4>:74: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
# <ipython-input-115-19e758966db4>:81: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rws = driver.find_element_by_xpath("//div[@class='reviews']")
# <ipython-input-115-19e758966db4>:87: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
# <ipython-input-115-19e758966db4>:94: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disc = driver.find_element_by_xpath("//div[@class='content']")

# %%
data = list(zip(hostel_name,distance,rating,reviews,over_all,pvt_prices,dorms_price,facilities,description))       
df = pd.DataFrame(data, columns = ["Hostel name","Distance from city centre","ratings","Total reviews",
                                   "Overall review","Privates from price","Dorms from price","Facilities","Property Description"])
df
# Out:
#                     Hostel name        Distance from city centre ratings  \
# 0   Smart Russell Square Hostel           2.6km from city centre     6.6
# 1       Smart Camden Inn Hostel           4.4km from city centre     8.4
# 2                 Selina Camden           5.5km from city centre     9.1
# 3       Queen Elizabeth Chelsea           5.7km from city centre     7.5
# 4          New Cross Inn Hostel           6.1km from city centre     7.2
# ..                          ...                              ...     ...
# 75      The Crystal Lodge Hotel  Hotel - 11.4km from city centre       -
# 76                    Kip Hotel   Hotel - 6.8km from city centre     9.1
# 77             Park Hotel Essex  Hotel - 24.1km from city centre     8.0
# 78              Cranbrook Hotel  Hotel - 14.8km from city centre       -
# 79       TLK Apartments & Hotel  Hotel - 19.9km from city centre       -
#
#    Total reviews Overall review Privates from price Dorms from price  \
# 0          9555            Good             Rs18461           Rs1586
# 1          2727        Fabulous             Rs18461           Rs1586
# 2            13          Superb             Rs18461           Rs1586
# 3          3208       Very Good             Rs18461           Rs1586
# 4          1041       Very Good             Rs18461           Rs1586
# ..           ...            ...                 ...              ...
# 75            0       No Rating             Rs13295           Rs1557
# 76           51          Superb             Rs13295           Rs1557
# 77          109        Fabulous             Rs13295           Rs1557
# 78            0       No Rating             Rs13295           Rs1557
# 79            0       No Rating             Rs13295           Rs1557
#
#                                          Facilities  \
# 0   Free WiFi, Follows Covid-19 sanitation guidance
# 1   Free WiFi, Follows Covid-19 sanitation guidance
# 2   Free WiFi, Follows Covid-19 sanitation guidance
# 3   Free WiFi, Follows Covid-19 sanitation guidance
# 4   Free WiFi, Follows Covid-19 sanitation guidance
# ..                                              ...
# 75  Free WiFi, Follows Covid-19 sanitation guidance
# 76  Free WiFi, Follows Covid-19 sanitation guidance
# 77  Free WiFi, Follows Covid-19 sanitation guidance
# 78  Free WiFi, Follows Covid-19 sanitation guidance
# 79  Free WiFi, Follows Covid-19 sanitation guidance
#
#                                  Property Description
# 0                 71 Guilford Street, London, England
# 1        55/57 Bayham Street, Camden, London, England
# 2       89 Chalk Farm Rd, Chalk Farm, London, England
# 3                    58 Bagleys Lane, London, England
# 4                 323 New Cross Road, London, England
# ..                                                ...
# 75                 49 Brigstock Road, London, England
# 76                   2 Aspland Grove, London, England
# 77        327 Cranbrook Road, Ilford, London, England
# 78       22/24 Coventry Road, Ilford, London, England
# 79  36-40 High Street, TLK Apartments & Hotel, Lon...
#
# [80 rows x 9 columns]
